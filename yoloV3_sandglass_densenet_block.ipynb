# %%
import os
import time
import shutil
import numpy as np
import tensorflow as tf
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/pankajrajput0312/yolov3_updation_work.git
# Out:
# Cloning into 'yolov3_updation_work'...
# remote: Enumerating objects: 94, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 94 (delta 9), reused 81 (delta 4), pack-reused 0
# Unpacking objects: 100% (94/94), done.

# %%
from easydict import EasyDict as edict


__C                           = edict()
# Consumers can get config by: from config import cfg

cfg                           = __C

# YOLO options
__C.YOLO                      = edict()

# Set the class name
__C.YOLO.CLASSES              = "/content/yolov3_updation_work/data/classes/coco.names"
__C.YOLO.ANCHORS              = "/content/yolov3_updation_work/data/anchors/basline_anchors.txt"
__C.YOLO.STRIDES              = [8, 16, 32]
__C.YOLO.ANCHOR_PER_SCALE     = 3
__C.YOLO.IOU_LOSS_THRESH      = 0.5

# Train options
__C.TRAIN                     = edict()

__C.TRAIN.ANNOT_PATH          = "/content/drive/MyDrive/yolov3_research_implementation/mnist_data/yymnist_train.txt"
__C.TRAIN.BATCH_SIZE          = 4
# __C.TRAIN.INPUT_SIZE            = [320, 352, 384, 416, 448, 480, 512, 544, 576, 608]
__C.TRAIN.INPUT_SIZE          = [416]
__C.TRAIN.DATA_AUG            = True
__C.TRAIN.LR_INIT             = 1e-3
__C.TRAIN.LR_END              = 1e-6
__C.TRAIN.WARMUP_EPOCHS       = 2
__C.TRAIN.EPOCHS              = 30



# TEST options
__C.TEST                      = edict()

__C.TEST.ANNOT_PATH           = "/content/drive/MyDrive/yolov3_research_implementation/mnist_data/yymnist_train.txt"
__C.TEST.BATCH_SIZE           = 2
__C.TEST.INPUT_SIZE           = 544
__C.TEST.DATA_AUG             = False
__C.TEST.DECTECTED_IMAGE_PATH = "./data/detection/"
__C.TEST.SCORE_THRESHOLD      = 0.3
__C.TEST.IOU_THRESHOLD        = 0.45

# %%
cfg
# Out:
# {'TEST': {'ANNOT_PATH': '/content/drive/MyDrive/yolov3_research_implementation/mnist_data/yymnist_train.txt',
#   'BATCH_SIZE': 2,
#   'DATA_AUG': False,
#   'DECTECTED_IMAGE_PATH': './data/detection/',
#   'INPUT_SIZE': 544,
#   'IOU_THRESHOLD': 0.45,
#   'SCORE_THRESHOLD': 0.3},
#  'TRAIN': {'ANNOT_PATH': '/content/drive/MyDrive/yolov3_research_implementation/mnist_data/yymnist_train.txt',
#   'BATCH_SIZE': 4,
#   'DATA_AUG': True,
#   'EPOCHS': 30,
#   'INPUT_SIZE': [416],
#   'LR_END': 1e-06,
#   'LR_INIT': 0.001,
#   'WARMUP_EPOCHS': 2},
#  'YOLO': {'ANCHORS': '/content/yolov3_updation_work/data/anchors/basline_anchors.txt',
#   'ANCHOR_PER_SCALE': 3,
#   'CLASSES': '/content/yolov3_updation_work/data/classes/coco.names',
#   'IOU_LOSS_THRESH': 0.5,
#   'STRIDES': [8, 16, 32]}}

# %% [markdown]
# # core.utils

# %%
import cv2
import random
import colorsys
import numpy as np

def load_weights(model, weights_file):
    """
    I agree that this code is very ugly, but I don’t know any better way of doing it.
    """
    wf = open(weights_file, 'rb')
    major, minor, revision, seen, _ = np.fromfile(wf, dtype=np.int32, count=5)

    j = 0
    for i in range(75):
        conv_layer_name = 'conv2d_%d' %i if i > 0 else 'conv2d'
        bn_layer_name = 'batch_normalization_%d' %j if j > 0 else 'batch_normalization'

        conv_layer = model.get_layer(conv_layer_name)
        filters = conv_layer.filters
        k_size = conv_layer.kernel_size[0]
        in_dim = conv_layer.input_shape[-1]

        if i not in [58, 66, 74]:
            # darknet weights: [beta, gamma, mean, variance]
            bn_weights = np.fromfile(wf, dtype=np.float32, count=4 * filters)
            # tf weights: [gamma, beta, mean, variance]
            bn_weights = bn_weights.reshape((4, filters))[[1, 0, 2, 3]]
            bn_layer = model.get_layer(bn_layer_name)
            j += 1
        else:
            conv_bias = np.fromfile(wf, dtype=np.float32, count=filters)

        # darknet shape (out_dim, in_dim, height, width)
        conv_shape = (filters, in_dim, k_size, k_size)
        conv_weights = np.fromfile(wf, dtype=np.float32, count=np.product(conv_shape))
        # tf shape (height, width, in_dim, out_dim)
        conv_weights = conv_weights.reshape(conv_shape).transpose([2, 3, 1, 0])

        if i not in [58, 66, 74]:
            conv_layer.set_weights([conv_weights])
            bn_layer.set_weights(bn_weights)
        else:
            conv_layer.set_weights([conv_weights, conv_bias])

    assert len(wf.read()) == 0, 'failed to read all data'
    wf.close()


def read_class_names(class_file_name):
    '''loads class name from a file'''
    names = {}
    with open(class_file_name, 'r') as data:
        for ID, name in enumerate(data):
            names[ID] = name.strip('\n')
    return names


def get_anchors(anchors_path):
    '''loads the anchors from a file'''
    with open(anchors_path) as f:
        anchors = f.readline()
    anchors = np.array(anchors.split(','), dtype=np.float32)
    return anchors.reshape(3, 3, 2)


def image_preporcess(image, target_size, gt_boxes=None):

    ih, iw    = target_size
    h,  w, _  = image.shape

    scale = min(iw/w, ih/h)
    nw, nh  = int(scale * w), int(scale * h)
    image_resized = cv2.resize(image, (nw, nh))

    image_paded = np.full(shape=[ih, iw, 3], fill_value=128.0)
    dw, dh = (iw - nw) // 2, (ih-nh) // 2
    image_paded[dh:nh+dh, dw:nw+dw, :] = image_resized
    image_paded = image_paded / 255.

    if gt_boxes is None:
        return image_paded

    else:
        gt_boxes[:, [0, 2]] = gt_boxes[:, [0, 2]] * scale + dw
        gt_boxes[:, [1, 3]] = gt_boxes[:, [1, 3]] * scale + dh
        return image_paded, gt_boxes


def draw_bbox(image, bboxes, classes=read_class_names(cfg.YOLO.CLASSES), show_label=True):
    """
    bboxes: [x_min, y_min, x_max, y_max, probability, cls_id] format coordinates.
    """

    num_classes = len(classes)
    image_h, image_w, _ = image.shape
    hsv_tuples = [(1.0 * x / num_classes, 1., 1.) for x in range(num_classes)]
    colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
    colors = list(map(lambda x: (int(x[0] * 255), int(x[1] * 255), int(x[2] * 255)), colors))

    random.seed(0)
    random.shuffle(colors)
    random.seed(None)

    for i, bbox in enumerate(bboxes):
        coor = np.array(bbox[:4], dtype=np.int32)
        fontScale = 0.5
        score = bbox[4]
        class_ind = int(bbox[5])
        bbox_color = colors[class_ind]
        bbox_thick = int(0.6 * (image_h + image_w) / 600)
        c1, c2 = (coor[0], coor[1]), (coor[2], coor[3])
        cv2.rectangle(image, c1, c2, bbox_color, bbox_thick)

        if show_label:
            bbox_mess = '%s: %.2f' % (classes[class_ind], score)
            t_size = cv2.getTextSize(bbox_mess, 0, fontScale, thickness=bbox_thick//2)[0]
            cv2.rectangle(image, c1, (c1[0] + t_size[0], c1[1] - t_size[1] - 3), bbox_color, -1)  # filled

            cv2.putText(image, bbox_mess, (c1[0], c1[1]-2), cv2.FONT_HERSHEY_SIMPLEX,
                        fontScale, (0, 0, 0), bbox_thick//2, lineType=cv2.LINE_AA)

    return image



def bboxes_iou(boxes1, boxes2):

    boxes1 = np.array(boxes1)
    boxes2 = np.array(boxes2)

    boxes1_area = (boxes1[..., 2] - boxes1[..., 0]) * (boxes1[..., 3] - boxes1[..., 1])
    boxes2_area = (boxes2[..., 2] - boxes2[..., 0]) * (boxes2[..., 3] - boxes2[..., 1])

    left_up       = np.maximum(boxes1[..., :2], boxes2[..., :2])
    right_down    = np.minimum(boxes1[..., 2:], boxes2[..., 2:])

    inter_section = np.maximum(right_down - left_up, 0.0)
    inter_area    = inter_section[..., 0] * inter_section[..., 1]
    union_area    = boxes1_area + boxes2_area - inter_area
    ious          = np.maximum(1.0 * inter_area / union_area, np.finfo(np.float32).eps)

    return ious


def nms(bboxes, iou_threshold, sigma=0.3, method='nms'):
    """
    :param bboxes: (xmin, ymin, xmax, ymax, score, class)

    Note: soft-nms, https://arxiv.org/pdf/1704.04503.pdf
          https://github.com/bharatsingh430/soft-nms
    """
    classes_in_img = list(set(bboxes[:, 5]))
    best_bboxes = []

    for cls in classes_in_img:
        cls_mask = (bboxes[:, 5] == cls)
        cls_bboxes = bboxes[cls_mask]

        while len(cls_bboxes) > 0:
            max_ind = np.argmax(cls_bboxes[:, 4])
            best_bbox = cls_bboxes[max_ind]
            best_bboxes.append(best_bbox)
            cls_bboxes = np.concatenate([cls_bboxes[: max_ind], cls_bboxes[max_ind + 1:]])
            iou = bboxes_iou(best_bbox[np.newaxis, :4], cls_bboxes[:, :4])
            weight = np.ones((len(iou),), dtype=np.float32)

            assert method in ['nms', 'soft-nms']

            if method == 'nms':
                iou_mask = iou > iou_threshold
                weight[iou_mask] = 0.0

            if method == 'soft-nms':
                weight = np.exp(-(1.0 * iou ** 2 / sigma))

            cls_bboxes[:, 4] = cls_bboxes[:, 4] * weight
            score_mask = cls_bboxes[:, 4] > 0.
            cls_bboxes = cls_bboxes[score_mask]

    return best_bboxes


def postprocess_boxes(pred_bbox, org_img_shape, input_size, score_threshold):

    valid_scale=[0, np.inf]
    pred_bbox = np.array(pred_bbox)

    pred_xywh = pred_bbox[:, 0:4]
    pred_conf = pred_bbox[:, 4]
    pred_prob = pred_bbox[:, 5:]

    # # (1) (x, y, w, h) --> (xmin, ymin, xmax, ymax)
    pred_coor = np.concatenate([pred_xywh[:, :2] - pred_xywh[:, 2:] * 0.5,
                                pred_xywh[:, :2] + pred_xywh[:, 2:] * 0.5], axis=-1)
    # # (2) (xmin, ymin, xmax, ymax) -> (xmin_org, ymin_org, xmax_org, ymax_org)
    org_h, org_w = org_img_shape
    resize_ratio = min(input_size / org_w, input_size / org_h)

    dw = (input_size - resize_ratio * org_w) / 2
    dh = (input_size - resize_ratio * org_h) / 2

    pred_coor[:, 0::2] = 1.0 * (pred_coor[:, 0::2] - dw) / resize_ratio
    pred_coor[:, 1::2] = 1.0 * (pred_coor[:, 1::2] - dh) / resize_ratio

    # # (3) clip some boxes those are out of range
    pred_coor = np.concatenate([np.maximum(pred_coor[:, :2], [0, 0]),
                                np.minimum(pred_coor[:, 2:], [org_w - 1, org_h - 1])], axis=-1)
    invalid_mask = np.logical_or((pred_coor[:, 0] > pred_coor[:, 2]), (pred_coor[:, 1] > pred_coor[:, 3]))
    pred_coor[invalid_mask] = 0

    # # (4) discard some invalid boxes
    bboxes_scale = np.sqrt(np.multiply.reduce(pred_coor[:, 2:4] - pred_coor[:, 0:2], axis=-1))
    scale_mask = np.logical_and((valid_scale[0] < bboxes_scale), (bboxes_scale < valid_scale[1]))

    # # (5) discard some boxes with low scores
    classes = np.argmax(pred_prob, axis=-1)
    scores = pred_conf * pred_prob[np.arange(len(pred_coor)), classes]
    score_mask = scores > score_threshold
    mask = np.logical_and(scale_mask, score_mask)
    coors, scores, classes = pred_coor[mask], scores[mask], classes[mask]

    return np.concatenate([coors, scores[:, np.newaxis], classes[:, np.newaxis]], axis=-1)

# %% [markdown]
# # Core.Dataset

# %%
class Dataset(object):
    """implement Dataset here"""
    def __init__(self, dataset_type):
        self.annot_path  = cfg.TRAIN.ANNOT_PATH if dataset_type == 'train' else cfg.TEST.ANNOT_PATH
        self.input_sizes = cfg.TRAIN.INPUT_SIZE if dataset_type == 'train' else cfg.TEST.INPUT_SIZE
        self.batch_size  = cfg.TRAIN.BATCH_SIZE if dataset_type == 'train' else cfg.TEST.BATCH_SIZE
        self.data_aug    = cfg.TRAIN.DATA_AUG   if dataset_type == 'train' else cfg.TEST.DATA_AUG

        self.train_input_sizes = cfg.TRAIN.INPUT_SIZE
        self.strides = np.array(cfg.YOLO.STRIDES)
        self.classes = read_class_names(cfg.YOLO.CLASSES)
        self.num_classes = len(self.classes)
        self.anchors = np.array(get_anchors(cfg.YOLO.ANCHORS))
        self.anchor_per_scale = cfg.YOLO.ANCHOR_PER_SCALE
        self.max_bbox_per_scale = 150

        self.annotations = self.load_annotations(dataset_type)
        self.num_samples = len(self.annotations)
        self.num_batchs = int(np.ceil(self.num_samples / self.batch_size))
        self.batch_count = 0


    def load_annotations(self, dataset_type):
        with open(self.annot_path, 'r') as f:
            txt = f.readlines()
            annotations = [line.strip() for line in txt if len(line.strip().split()[1:]) != 0]
        np.random.shuffle(annotations)
        return annotations

    def __iter__(self):
        return self

    def __next__(self):

        with tf.device('/cpu:0'):
            self.train_input_size = random.choice(self.train_input_sizes)
            self.train_output_sizes = self.train_input_size // self.strides

            batch_image = np.zeros((self.batch_size, self.train_input_size, self.train_input_size, 3), dtype=np.float32)

            batch_label_sbbox = np.zeros((self.batch_size, self.train_output_sizes[0], self.train_output_sizes[0],
                                          self.anchor_per_scale, 5 + self.num_classes), dtype=np.float32)
            batch_label_mbbox = np.zeros((self.batch_size, self.train_output_sizes[1], self.train_output_sizes[1],
                                          self.anchor_per_scale, 5 + self.num_classes), dtype=np.float32)
            batch_label_lbbox = np.zeros((self.batch_size, self.train_output_sizes[2], self.train_output_sizes[2],
                                          self.anchor_per_scale, 5 + self.num_classes), dtype=np.float32)

            batch_sbboxes = np.zeros((self.batch_size, self.max_bbox_per_scale, 4), dtype=np.float32)
            batch_mbboxes = np.zeros((self.batch_size, self.max_bbox_per_scale, 4), dtype=np.float32)
            batch_lbboxes = np.zeros((self.batch_size, self.max_bbox_per_scale, 4), dtype=np.float32)

            num = 0
            if self.batch_count < self.num_batchs:
                while num < self.batch_size:
                    index = self.batch_count * self.batch_size + num
                    if index >= self.num_samples: index -= self.num_samples
                    annotation = self.annotations[index]
                    image, bboxes = self.parse_annotation(annotation)
                    label_sbbox, label_mbbox, label_lbbox, sbboxes, mbboxes, lbboxes = self.preprocess_true_boxes(bboxes)

                    batch_image[num, :, :, :] = image
                    batch_label_sbbox[num, :, :, :, :] = label_sbbox
                    batch_label_mbbox[num, :, :, :, :] = label_mbbox
                    batch_label_lbbox[num, :, :, :, :] = label_lbbox
                    batch_sbboxes[num, :, :] = sbboxes
                    batch_mbboxes[num, :, :] = mbboxes
                    batch_lbboxes[num, :, :] = lbboxes
                    num += 1
                self.batch_count += 1
                batch_smaller_target = batch_label_sbbox, batch_sbboxes
                batch_medium_target  = batch_label_mbbox, batch_mbboxes
                batch_larger_target  = batch_label_lbbox, batch_lbboxes

                return batch_image, (batch_smaller_target, batch_medium_target, batch_larger_target)
            else:
                self.batch_count = 0
                np.random.shuffle(self.annotations)
                raise StopIteration

    def random_horizontal_flip(self, image, bboxes):

        if random.random() < 0.5:
            _, w, _ = image.shape
            image = image[:, ::-1, :]
            bboxes[:, [0,2]] = w - bboxes[:, [2,0]]

        return image, bboxes

    def random_crop(self, image, bboxes):

        if random.random() < 0.5:
            h, w, _ = image.shape
            max_bbox = np.concatenate([np.min(bboxes[:, 0:2], axis=0), np.max(bboxes[:, 2:4], axis=0)], axis=-1)

            max_l_trans = max_bbox[0]
            max_u_trans = max_bbox[1]
            max_r_trans = w - max_bbox[2]
            max_d_trans = h - max_bbox[3]

            crop_xmin = max(0, int(max_bbox[0] - random.uniform(0, max_l_trans)))
            crop_ymin = max(0, int(max_bbox[1] - random.uniform(0, max_u_trans)))
            crop_xmax = max(w, int(max_bbox[2] + random.uniform(0, max_r_trans)))
            crop_ymax = max(h, int(max_bbox[3] + random.uniform(0, max_d_trans)))

            image = image[crop_ymin : crop_ymax, crop_xmin : crop_xmax]

            bboxes[:, [0, 2]] = bboxes[:, [0, 2]] - crop_xmin
            bboxes[:, [1, 3]] = bboxes[:, [1, 3]] - crop_ymin

        return image, bboxes

    def random_translate(self, image, bboxes):

        if random.random() < 0.5:
            h, w, _ = image.shape
            max_bbox = np.concatenate([np.min(bboxes[:, 0:2], axis=0), np.max(bboxes[:, 2:4], axis=0)], axis=-1)

            max_l_trans = max_bbox[0]
            max_u_trans = max_bbox[1]
            max_r_trans = w - max_bbox[2]
            max_d_trans = h - max_bbox[3]

            tx = random.uniform(-(max_l_trans - 1), (max_r_trans - 1))
            ty = random.uniform(-(max_u_trans - 1), (max_d_trans - 1))

            M = np.array([[1, 0, tx], [0, 1, ty]])
            image = cv2.warpAffine(image, M, (w, h))

            bboxes[:, [0, 2]] = bboxes[:, [0, 2]] + tx
            bboxes[:, [1, 3]] = bboxes[:, [1, 3]] + ty

        return image, bboxes

    def parse_annotation(self, annotation):

        line = annotation.split()
        image_path = line[0]
        if not os.path.exists(image_path):
            raise KeyError("%s does not exist ... " %image_path)
        image = cv2.imread(image_path)
        bboxes = np.array([list(map(int, box.split(','))) for box in line[1:]])

        if self.data_aug:
            image, bboxes = self.random_horizontal_flip(np.copy(image), np.copy(bboxes))
            image, bboxes = self.random_crop(np.copy(image), np.copy(bboxes))
            image, bboxes = self.random_translate(np.copy(image), np.copy(bboxes))

        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image, bboxes = image_preporcess(np.copy(image), [self.train_input_size, self.train_input_size], np.copy(bboxes))
        return image, bboxes

    def bbox_iou(self, boxes1, boxes2):

        boxes1 = np.array(boxes1)
        boxes2 = np.array(boxes2)

        boxes1_area = boxes1[..., 2] * boxes1[..., 3]
        boxes2_area = boxes2[..., 2] * boxes2[..., 3]

        boxes1 = np.concatenate([boxes1[..., :2] - boxes1[..., 2:] * 0.5,
                                boxes1[..., :2] + boxes1[..., 2:] * 0.5], axis=-1)
        boxes2 = np.concatenate([boxes2[..., :2] - boxes2[..., 2:] * 0.5,
                                boxes2[..., :2] + boxes2[..., 2:] * 0.5], axis=-1)

        left_up = np.maximum(boxes1[..., :2], boxes2[..., :2])
        right_down = np.minimum(boxes1[..., 2:], boxes2[..., 2:])

        inter_section = np.maximum(right_down - left_up, 0.0)
        inter_area = inter_section[..., 0] * inter_section[..., 1]
        union_area = boxes1_area + boxes2_area - inter_area

        return inter_area / union_area

    def preprocess_true_boxes(self, bboxes):

        label = [np.zeros((self.train_output_sizes[i], self.train_output_sizes[i], self.anchor_per_scale,
                           5 + self.num_classes)) for i in range(3)]
        bboxes_xywh = [np.zeros((self.max_bbox_per_scale, 4)) for _ in range(3)]
        bbox_count = np.zeros((3,))

        for bbox in bboxes:
            bbox_coor = bbox[:4]
            bbox_class_ind = bbox[4]

            onehot = np.zeros(self.num_classes, dtype=np.float)
            onehot[bbox_class_ind] = 1.0
            uniform_distribution = np.full(self.num_classes, 1.0 / self.num_classes)
            deta = 0.01
            smooth_onehot = onehot * (1 - deta) + deta * uniform_distribution

            bbox_xywh = np.concatenate([(bbox_coor[2:] + bbox_coor[:2]) * 0.5, bbox_coor[2:] - bbox_coor[:2]], axis=-1)
            bbox_xywh_scaled = 1.0 * bbox_xywh[np.newaxis, :] / self.strides[:, np.newaxis]

            iou = []
            exist_positive = False
            for i in range(3):
                anchors_xywh = np.zeros((self.anchor_per_scale, 4))
                anchors_xywh[:, 0:2] = np.floor(bbox_xywh_scaled[i, 0:2]).astype(np.int32) + 0.5
                anchors_xywh[:, 2:4] = self.anchors[i]

                iou_scale = self.bbox_iou(bbox_xywh_scaled[i][np.newaxis, :], anchors_xywh)
                iou.append(iou_scale)
                iou_mask = iou_scale > 0.3

                if np.any(iou_mask):
                    xind, yind = np.floor(bbox_xywh_scaled[i, 0:2]).astype(np.int32)

                    label[i][yind, xind, iou_mask, :] = 0
                    label[i][yind, xind, iou_mask, 0:4] = bbox_xywh
                    label[i][yind, xind, iou_mask, 4:5] = 1.0
                    label[i][yind, xind, iou_mask, 5:] = smooth_onehot

                    bbox_ind = int(bbox_count[i] % self.max_bbox_per_scale)
                    bboxes_xywh[i][bbox_ind, :4] = bbox_xywh
                    bbox_count[i] += 1

                    exist_positive = True

            if not exist_positive:
                best_anchor_ind = np.argmax(np.array(iou).reshape(-1), axis=-1)
                best_detect = int(best_anchor_ind / self.anchor_per_scale)
                best_anchor = int(best_anchor_ind % self.anchor_per_scale)
                xind, yind = np.floor(bbox_xywh_scaled[best_detect, 0:2]).astype(np.int32)

                label[best_detect][yind, xind, best_anchor, :] = 0
                label[best_detect][yind, xind, best_anchor, 0:4] = bbox_xywh
                label[best_detect][yind, xind, best_anchor, 4:5] = 1.0
                label[best_detect][yind, xind, best_anchor, 5:] = smooth_onehot

                bbox_ind = int(bbox_count[best_detect] % self.max_bbox_per_scale)
                bboxes_xywh[best_detect][bbox_ind, :4] = bbox_xywh
                bbox_count[best_detect] += 1
        label_sbbox, label_mbbox, label_lbbox = label
        sbboxes, mbboxes, lbboxes = bboxes_xywh
        return label_sbbox, label_mbbox, label_lbbox, sbboxes, mbboxes, lbboxes

    def __len__(self):
        return self.num_batchs

# %% [markdown]
# # Building block

# %%
import tensorflow as tf

class BatchNormalization(tf.keras.layers.BatchNormalization):
    """
    "Frozen state" and "inference mode" are two separate concepts.
    `layer.trainable = False` is to freeze the layer, so the layer will use
    stored moving `var` and `mean` in the "inference mode", and both `gama`
    and `beta` will not be updated !
    """
    def call(self, x, training=False):
        if not training:
            training = tf.constant(False)
        training = tf.logical_and(training, self.trainable)
        return super().call(x, training)

# %%
def convolutional(input_layer, filters_shape, downsample=False, activate=True, bn=True):
    if downsample:
        input_layer = tf.keras.layers.ZeroPadding2D(((1, 0), (1, 0)))(input_layer)
        padding = 'valid'
        strides = 2
    else:
        strides = 1
        padding = 'same'

    conv = tf.keras.layers.Conv2D(filters=filters_shape[-1], kernel_size = filters_shape[0], strides=strides, padding=padding,
                                  use_bias=not bn, kernel_regularizer=tf.keras.regularizers.l2(0.0005),
                                  kernel_initializer=tf.random_normal_initializer(stddev=0.01),
                                  bias_initializer=tf.constant_initializer(0.))(input_layer)

    if bn: conv = BatchNormalization()(conv)
    if activate == True: conv = tf.nn.leaky_relu(conv, alpha=0.1)

    return conv

# %%
def residual_block(input_layer, input_channel, filter_num1, filter_num2):
    short_cut = input_layer
    conv = convolutional(input_layer, filters_shape=(1, 1, input_channel, filter_num1))
    conv = convolutional(conv       , filters_shape=(3, 3, filter_num1,   filter_num2))

    residual_output = short_cut + conv
    return residual_output

# %%
image = tf.zeros(
    (1, 224,224,5), dtype=tf.dtypes.float32, name=None
)
output = residual_block(image, 5, 5, 5)

# %%
def upsample(input_layer):
    return tf.image.resize(input_layer, (input_layer.shape[1] * 2, input_layer.shape[2] * 2), method='nearest')

# %%
print(output.shape)
# Out:
# (1, 224, 224, 5)

# %%
def depth_wise_conv(input_layer, filters_shape, downsample=False, activate=True, bn=True):
    if downsample:
        input_layer = tf.keras.layers.ZeroPadding2D(((1, 0), (1, 0)))(input_layer)
        strides = 2
    else:
        strides = 1
    '''
        need to implemenet depthwise convolution layer
    '''
    conv =tf.keras.layers.DepthwiseConv2D(
                                  kernel_size = (filters_shape[0],filters_shape[1]), strides=strides, padding='same', depth_multiplier=1,
                                  data_format=None, dilation_rate=(1, 1), activation=None, use_bias=not bn,
                                  depthwise_initializer='glorot_uniform',
                                  bias_initializer=tf.constant_initializer(0.), depthwise_regularizer=None,
                                  bias_regularizer=None, activity_regularizer=None, depthwise_constraint=None,
                                  bias_constraint=None
                              )(input_layer)

    if bn: conv = BatchNormalization()(conv)
    if activate == True: conv = tf.nn.leaky_relu(conv, alpha=0.1)
    return conv

# %%
def pointwise_conv(input_layer, output_channel, activate = True):
    conv =tf.keras.layers.Conv1D(output_channel, 1, strides=1, padding='valid', kernel_regularizer=tf.keras.regularizers.l2(0.0005),
                                  kernel_initializer=tf.random_normal_initializer(stddev=0.01),
                                  bias_initializer=tf.constant_initializer(0.))(input_layer)
    if activate == True: conv = tf.nn.leaky_relu(conv, alpha = 0.1)
    return conv

# %%
def sandglass_block(input_layer,input_channel, filter_num1, filter_num2):
    short_cut = input_layer
    conv = depth_wise_conv(input_layer, filters_shape=(3,3))
    conv = pointwise_conv(input_layer=conv, output_channel=filter_num1, activate = False)
    conv = pointwise_conv(input_layer=conv, output_channel=filter_num2, activate = True)
    conv = depth_wise_conv(input_layer, filters_shape=(3,3))
    sandglass_residual_output = short_cut + conv
    return sandglass_residual_output

# %%
image = tf.zeros(
    (1, 224,224,5), dtype=tf.dtypes.float32, name=None
)

# %%
output_1d = pointwise_conv(image, 124)

# %%
output_sandglass_block = sandglass_block(image, 5, 124, 5)

# %%
print(output_sandglass_block.shape)
# Out:
# (1, 224, 224, 5)

# %%
output = depth_wise_conv(image, (3,3))

# %%
print(output.shape)
# Out:
# (1, 224, 224, 5)

# %%
conv_output = convolutional(image,filters_shape=(1, 1, 5, 5) )

# %%
print(conv_output.shape)
# Out:
# (1, 224, 224, 5)

# %%
# tf.keras.layers.DepthwiseConv2D(
#     kernel_size, strides=(3, 3), padding='valid', depth_multiplier=1,
#     data_format=None, dilation_rate=(1, 1), activation=None, use_bias=True,
#     depthwise_initializer='glorot_uniform',
#     bias_initializer='zeros', depthwise_regularizer=None,
#     bias_regularizer=None, activity_regularizer=None, depthwise_constraint=None,
#     bias_constraint=None, **kwargs
# )

# %%
def densenet(input_layer, input_channel, filter_num1, filter_num2):
    h1_conv = input_layer
    conv = convolutional(input_layer, filters_shape=(1, 1, input_channel, filter_num1))
    conv = convolutional(conv       , filters_shape=(3, 3, filter_num1,   filter_num2))

    h2_conv = conv
    conv = h1_conv+conv
    conv = convolutional(conv, filters_shape=(1, 1, input_channel, filter_num1))
    conv = convolutional(conv, filters_shape=(3, 3, filter_num1,   filter_num2))

    h3_conv = conv
    conv = h2_conv+h1_conv+conv
    conv = convolutional(conv, filters_shape=(1, 1, input_channel, filter_num1))
    conv = convolutional(conv       , filters_shape=(3, 3, filter_num1,   filter_num2))

    h4_conv = conv
    conv = h3_conv + h2_conv + h1_conv + conv
    conv = convolutional(conv, filters_shape=(1, 1, input_channel, filter_num1))
    conv = convolutional(conv, filters_shape=(3, 3, filter_num1,   filter_num2))
    
    dense_output = h1_conv + h2_conv + h3_conv + h4_conv+conv
    return dense_output

# %%
image = tf.zeros(
    (1, 52,52,256), dtype=tf.dtypes.float32, name=None
)
output = densenet(image, 256, 128, 256)

# %%
print(output.shape)
# Out:
# (1, 52, 52, 256)

# %% [markdown]
# # Core.Backbone

# %%
import tensorflow


def darknet53(input_data):

    input_data = convolutional(input_data, (3, 3,  3,  32))
    input_data = convolutional(input_data, (3, 3, 32,  64), downsample=True)

    for i in range(1):
        input_data = sandglass_block(input_data,  64,  32, 64)

    input_data = convolutional(input_data, (3, 3,  64, 128), downsample=True)

    for i in range(2):
        input_data = sandglass_block(input_data, 128,  64, 128)

    input_data = convolutional(input_data, (3, 3, 128, 256), downsample=True)

    for i in range(4):
        input_data = sandglass_block(input_data, 256, 128, 256)
    
    for i in range(4):
        input_data = sandglass_block(input_data, 256, 128, 256)

    route_1 = input_data
    input_data = convolutional(input_data, (3, 3, 256, 512), downsample=True)

    for i in range(8):
        input_data = sandglass_block(input_data, 512, 256, 512)

    route_2 = input_data
    input_data = convolutional(input_data, (3, 3, 512, 1024), downsample=True)

    for i in range(4):
        input_data = sandglass_block(input_data, 1024, 512, 1024)

    return route_1, route_2, input_data

# %% [markdown]
# ### darknet53 with the densenet block

# %%
import tensorflow

def darknet53_dense_block(input_data):

    input_data = convolutional(input_data, (3, 3,  3,  32))
    input_data = convolutional(input_data, (3, 3, 32,  64), downsample=True)

    for i in range(1):
        input_data = sandglass_block(input_data,  64,  32, 64)

    input_data = convolutional(input_data, (3, 3,  64, 128), downsample=True)

    for i in range(2):
        input_data = sandglass_block(input_data, 128,  64, 128)

    input_data = convolutional(input_data, (3, 3, 128, 256), downsample=True)

    # for i in range(4):
    #     input_data = sandglass_block(input_data, 256, 128, 256)
    
    # for i in range(4):
    #     input_data = sandglass_block(input_data, 256, 128, 256)
    for i in range(2):
        input_data = densenet(input_data, 256, 128, 256)

    route_1 = input_data
    input_data = convolutional(input_data, (3, 3, 256, 512), downsample=True)

    for i in range(2):
        input_data = densenet(input_data, 512, 256, 512)

    route_2 = input_data
    input_data = convolutional(input_data, (3, 3, 512, 1024), downsample=True)

    for i in range(4):
        input_data = sandglass_block(input_data, 1024, 512, 1024)

    return route_1, route_2, input_data

# %%
image = tf.zeros(
    (1, 416,416,3), dtype=tf.dtypes.float32, name=None
)
darknet_output = darknet53(image)

# %%
route_1, route_2, input_data = darknet_output
print(route_1.shape)
print(route_2.shape)
print(input_data.shape)
# Out:
# (1, 52, 52, 256)
# (1, 26, 26, 512)
# (1, 13, 13, 1024)

# %%
darknet_dense_output = darknet53_dense_block(image)

# %%
route_1, route_2, input_data = darknet_dense_output
print(route_1.shape)
print(route_2.shape)
print(input_data.shape)
# Out:
# (1, 52, 52, 256)
# (1, 26, 26, 512)
# (1, 13, 13, 1024)

# %% [markdown]
# # Core.yolov3

# %%
import numpy as np
import tensorflow as tf



NUM_CLASS       = len(read_class_names(cfg.YOLO.CLASSES))
ANCHORS         = get_anchors(cfg.YOLO.ANCHORS)
STRIDES         = np.array(cfg.YOLO.STRIDES)
IOU_LOSS_THRESH = cfg.YOLO.IOU_LOSS_THRESH

# %%
def YOLOv3(input_layer):
    route_1, route_2, conv = darknet53_dense_block(input_layer)

    conv = convolutional(conv, (1, 1, 1024,  512))
    conv = convolutional(conv, (3, 3,  512, 1024))
    conv = convolutional(conv, (1, 1, 1024,  512))
    conv = convolutional(conv, (3, 3,  512, 1024))
    conv = convolutional(conv, (1, 1, 1024,  512))

    conv_lobj_branch = convolutional(conv, (3, 3, 512, 1024))
    conv_lbbox = convolutional(conv_lobj_branch, (1, 1, 1024, 3*(NUM_CLASS + 5)), activate=False, bn=False)

    conv = convolutional(conv, (1, 1,  512,  256))
    conv = upsample(conv)

    conv = tf.concat([conv, route_2], axis=-1)

    conv = convolutional(conv, (1, 1, 768, 256))
    conv = convolutional(conv, (3, 3, 256, 512))
    conv = convolutional(conv, (1, 1, 512, 256))
    conv = convolutional(conv, (3, 3, 256, 512))
    conv = convolutional(conv, (1, 1, 512, 256))

    conv_mobj_branch = convolutional(conv, (3, 3, 256, 512))
    conv_mbbox = convolutional(conv_mobj_branch, (1, 1, 512, 3*(NUM_CLASS + 5)), activate=False, bn=False)

    conv = convolutional(conv, (1, 1, 256, 128))
    conv = upsample(conv)

    conv = tf.concat([conv, route_1], axis=-1)

    conv = convolutional(conv, (1, 1, 384, 128))
    conv = convolutional(conv, (3, 3, 128, 256))
    conv = convolutional(conv, (1, 1, 256, 128))
    conv = convolutional(conv, (3, 3, 128, 256))
    conv = convolutional(conv, (1, 1, 256, 128))

    conv_sobj_branch = convolutional(conv, (3, 3, 128, 256))
    conv_sbbox = convolutional(conv_sobj_branch, (1, 1, 256, 3*(NUM_CLASS +5)), activate=False, bn=False)

    return [conv_sbbox, conv_mbbox, conv_lbbox]

# %%
def decode(conv_output, i=0):
    """
    return tensor of shape [batch_size, output_size, output_size, anchor_per_scale, 5 + num_classes]
            contains (x, y, w, h, score, probability)
    """

    conv_shape       = tf.shape(conv_output)
    batch_size       = conv_shape[0]
    output_size      = conv_shape[1]

    conv_output = tf.reshape(conv_output, (batch_size, output_size, output_size, 3, 5 + NUM_CLASS))

    conv_raw_dxdy = conv_output[:, :, :, :, 0:2]
    conv_raw_dwdh = conv_output[:, :, :, :, 2:4]
    conv_raw_conf = conv_output[:, :, :, :, 4:5]
    conv_raw_prob = conv_output[:, :, :, :, 5: ]

    y = tf.tile(tf.range(output_size, dtype=tf.int32)[:, tf.newaxis], [1, output_size])
    x = tf.tile(tf.range(output_size, dtype=tf.int32)[tf.newaxis, :], [output_size, 1])

    xy_grid = tf.concat([x[:, :, tf.newaxis], y[:, :, tf.newaxis]], axis=-1)
    xy_grid = tf.tile(xy_grid[tf.newaxis, :, :, tf.newaxis, :], [batch_size, 1, 1, 3, 1])
    xy_grid = tf.cast(xy_grid, tf.float32)

    pred_xy = (tf.sigmoid(conv_raw_dxdy) + xy_grid) * STRIDES[i]
    pred_wh = (tf.exp(conv_raw_dwdh) * ANCHORS[i]) * STRIDES[i]
    pred_xywh = tf.concat([pred_xy, pred_wh], axis=-1)

    pred_conf = tf.sigmoid(conv_raw_conf)
    pred_prob = tf.sigmoid(conv_raw_prob)

    return tf.concat([pred_xywh, pred_conf, pred_prob], axis=-1)

# %%
def bbox_iou(boxes1, boxes2):

    boxes1_area = boxes1[..., 2] * boxes1[..., 3]
    boxes2_area = boxes2[..., 2] * boxes2[..., 3]

    boxes1 = tf.concat([boxes1[..., :2] - boxes1[..., 2:] * 0.5,
                        boxes1[..., :2] + boxes1[..., 2:] * 0.5], axis=-1)
    boxes2 = tf.concat([boxes2[..., :2] - boxes2[..., 2:] * 0.5,
                        boxes2[..., :2] + boxes2[..., 2:] * 0.5], axis=-1)

    left_up = tf.maximum(boxes1[..., :2], boxes2[..., :2])
    right_down = tf.minimum(boxes1[..., 2:], boxes2[..., 2:])

    inter_section = tf.maximum(right_down - left_up, 0.0)
    inter_area = inter_section[..., 0] * inter_section[..., 1]
    union_area = boxes1_area + boxes2_area - inter_area

    return 1.0 * inter_area / union_area

# %%
def bbox_giou(boxes1, boxes2):

    boxes1 = tf.concat([boxes1[..., :2] - boxes1[..., 2:] * 0.5,
                        boxes1[..., :2] + boxes1[..., 2:] * 0.5], axis=-1)
    boxes2 = tf.concat([boxes2[..., :2] - boxes2[..., 2:] * 0.5,
                        boxes2[..., :2] + boxes2[..., 2:] * 0.5], axis=-1)

    boxes1 = tf.concat([tf.minimum(boxes1[..., :2], boxes1[..., 2:]),
                        tf.maximum(boxes1[..., :2], boxes1[..., 2:])], axis=-1)
    boxes2 = tf.concat([tf.minimum(boxes2[..., :2], boxes2[..., 2:]),
                        tf.maximum(boxes2[..., :2], boxes2[..., 2:])], axis=-1)

    boxes1_area = (boxes1[..., 2] - boxes1[..., 0]) * (boxes1[..., 3] - boxes1[..., 1])
    boxes2_area = (boxes2[..., 2] - boxes2[..., 0]) * (boxes2[..., 3] - boxes2[..., 1])

    left_up = tf.maximum(boxes1[..., :2], boxes2[..., :2])
    right_down = tf.minimum(boxes1[..., 2:], boxes2[..., 2:])

    inter_section = tf.maximum(right_down - left_up, 0.0)
    inter_area = inter_section[..., 0] * inter_section[..., 1]
    union_area = boxes1_area + boxes2_area - inter_area
    iou = inter_area / union_area

    enclose_left_up = tf.minimum(boxes1[..., :2], boxes2[..., :2])
    enclose_right_down = tf.maximum(boxes1[..., 2:], boxes2[..., 2:])
    enclose = tf.maximum(enclose_right_down - enclose_left_up, 0.0)
    enclose_area = enclose[..., 0] * enclose[..., 1]
    giou = iou - 1.0 * (enclose_area - union_area) / enclose_area

    return giou

# %%
def compute_loss(pred, conv, label, bboxes, i=0):

    conv_shape  = tf.shape(conv)
    batch_size  = conv_shape[0]
    output_size = conv_shape[1]
    input_size  = STRIDES[i] * output_size
    conv = tf.reshape(conv, (batch_size, output_size, output_size, 3, 5 + NUM_CLASS))

    conv_raw_conf = conv[:, :, :, :, 4:5]
    conv_raw_prob = conv[:, :, :, :, 5:]

    pred_xywh     = pred[:, :, :, :, 0:4]
    pred_conf     = pred[:, :, :, :, 4:5]

    label_xywh    = label[:, :, :, :, 0:4]
    respond_bbox  = label[:, :, :, :, 4:5]
    label_prob    = label[:, :, :, :, 5:]

    giou = tf.expand_dims(bbox_giou(pred_xywh, label_xywh), axis=-1)
    input_size = tf.cast(input_size, tf.float32)

    bbox_loss_scale = 2.0 - 1.0 * label_xywh[:, :, :, :, 2:3] * label_xywh[:, :, :, :, 3:4] / (input_size ** 2)
    giou_loss = respond_bbox * bbox_loss_scale * (1- giou)

    iou = bbox_iou(pred_xywh[:, :, :, :, np.newaxis, :], bboxes[:, np.newaxis, np.newaxis, np.newaxis, :, :])
    max_iou = tf.expand_dims(tf.reduce_max(iou, axis=-1), axis=-1)

    respond_bgd = (1.0 - respond_bbox) * tf.cast( max_iou < IOU_LOSS_THRESH, tf.float32 )

    conf_focal = tf.pow(respond_bbox - pred_conf, 2)

    conf_loss = conf_focal * (
            respond_bbox * tf.nn.sigmoid_cross_entropy_with_logits(labels=respond_bbox, logits=conv_raw_conf)
            +
            respond_bgd * tf.nn.sigmoid_cross_entropy_with_logits(labels=respond_bbox, logits=conv_raw_conf)
    )

    prob_loss = respond_bbox * tf.nn.sigmoid_cross_entropy_with_logits(labels=label_prob, logits=conv_raw_prob)

    giou_loss = tf.reduce_mean(tf.reduce_sum(giou_loss, axis=[1,2,3,4]))
    conf_loss = tf.reduce_mean(tf.reduce_sum(conf_loss, axis=[1,2,3,4]))
    prob_loss = tf.reduce_mean(tf.reduce_sum(prob_loss, axis=[1,2,3,4]))

    return giou_loss, conf_loss, prob_loss

# %% [markdown]
# # Create Dataset

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# !git clone https://github.com/YunYang1994/yymnist.git
# Out:
# Cloning into 'yymnist'...
# remote: Enumerating objects: 65040, done.
# remote: Total 65040 (delta 0), reused 0 (delta 0), pack-reused 65040
# Receiving objects: 100% (65040/65040), 14.69 MiB | 19.34 MiB/s, done.
# Resolving deltas: 100% (36315/36315), done.
# Checking out files: 100% (65007/65007), done.

# %%
try:
  os.mkdir("/content/drive/MyDrive/yolov3_research_implementation/mnist_data")
except Exception as e:
  print(e)
try:
  os.mkdir("/content/drive/MyDrive/yolov3_research_implementation/mnist_data/train")
except Exception as e:
  print(e)
try:
  os.mkdir("/content/drive/MyDrive/yolov3_research_implementation/mnist_data/test")
except Exception as e:
  print(e)

# %%
# !python yymnist/make_data.py --images_num 1000 --images_path /content/drive/MyDrive/yolov3_research_implementation/mnist_data/train --labels_txt /content/drive/MyDrive/yolov3_research_implementation/mnist_data/yymnist_train.txt
# !python yymnist/make_data.py --images_num 200  --images_path /content/drive/MyDrive/yolov3_research_implementation/mnist_data/test  --labels_txt /content/drive/MyDrive/yolov3_research_implementation/mnist_data/yymnist_test.txt
# Out:
# => /content/drive/MyDrive/yolov3_research_implementation/mnist_data/train/000001.jpg 35,120,57,142,1 341,320,355,334,0 251,86,273,108,8 38,233,80,275,6 22,168,78,224,8 281,225,337,281,1 119,105,161,147,2 121,315,177,371,4 19,318,103,402,1 213,290,325,402,3 139,4,223,88,5
# => /content/drive/MyDrive/yolov3_research_implementation/mnist_data/train/000002.jpg 329,284,343,298,0 244,201,272,229,3 277,27,333,83,0 158,360,186,388,1 331,176,373,218,2 92,49,204,161,7 80,208,192,320,4
# => /content/drive/MyDrive/yolov3_research_implementation/mnist_data/train/000003.jpg 143,62,165,84,0 187,356,201,370,5 128,147,170,189,9 178,252,234,308,8 225,95,281,151,2 43,294,71,322,1 377,373,405,401,2 279,100,391,212,7 6,29,118,141,6
# => /content/drive/MyDrive/yolov3_research_implementation/mnist_data/train/000004.jpg 295,320,317,342,6 277,109,333,165,0
# => /content/drive/MyDrive/yolov3_research_implementation/mnist_data/train/
# => /content/drive/MyDrive/yolov3_research_implementation/mnist_data/test/000196.jpg 211,362,225,376,1 12,166,26,180,9 64,50,106,92,6 35,179,63,207,9 214,29,298,113,0 85,242,197,354,8 296,187,380,271,0
# => /content/drive/MyDrive/yolov3_research_implementation/mnist_data/test/000197.jpg 217,349,239,371,7 97,257,119,279,8 70,305,98,333,0 226,247,282,303,0 315,18,371,74,8 196,71,238,113,9 331,157,387,213,5 16,86,128,198,6 134,228,218,312,7
# => /content/drive/MyDrive/yolov3_research_implementation/mnist_data/test/000198.jpg 131,62,145,76,9 176,287,190,301,4 388,337,410,359,8 267,132,323,188,9 199,26,241,68,3 44,44,128,128,1 195,207,307,319,6 12,257,96,341,3
# => /content/drive/MyDrive/yolov3_research_implementation/mnist_data/test/000199.jpg 66,211,88,233,8 315,346,337,368,7 206,315,262,371,2 205,73,289,157,3
# => /content/drive/MyDrive/yolov3_research_implementation/mnist_data/test/000200.jpg 353,211,367,225,6 73,355,129,411,0 349,63,391,105,7 159,311,187,339,1 295,140,407,252,5

# %% [markdown]
# # Model Compilng

# %%
input_tensor = tf.keras.layers.Input([416, 416, 3])
conv_tensors = YOLOv3(input_tensor)

output_tensors = []
for i, conv_tensor in enumerate(conv_tensors):
    pred_tensor = decode(conv_tensor, i)
    output_tensors.append(conv_tensor)
    output_tensors.append(pred_tensor)

model = tf.keras.Model(input_tensor, output_tensors)
optimizer = tf.keras.optimizers.Adam()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 416, 416, 3  0           []
#                                 )]
#
#  conv2d_212 (Conv2D)            (None, 416, 416, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization_458 (Batch  (None, 416, 416, 32  128        ['conv2d_212[0][0]']
#  Normalization)                 )
#
#  tf.nn.leaky_relu (TFOpLambda)  (None, 416, 416, 32  0           ['batch_normalization_458[0][0]']
#                                 )
#
#  zero_padding2d_40 (ZeroPadding  (None, 417, 417, 32  0          ['tf.nn.leaky_relu[0][0]']
#  2D)                            )
#
#  conv2d_213 (Conv2D)            (None, 208, 208, 64  18432       ['zero_padding2d_40[0][0]']
#                                 )
#
#  batch_normalization_459 (Batch  (None, 208, 208, 64  256        ['conv2d_213[0][0]']
#  Normalization)                 )
#
#  tf.nn.leaky_relu_1 (TFOpLambda  (None, 208, 208, 64  0          ['batch_normalization_459[0][0]']
#  )                              )
#
#  depthwise_conv2d_247 (Depthwis  (None, 208, 208, 64  576        ['tf.nn.leaky_relu_1[0][0]']
#  eConv2D)                       )
#
#  batch_normalization_461 (Batch  (None, 208, 208, 64  256        ['depthwise_conv2d_247[0][0]']
#  Normalization)                 )
#
#  tf.nn.leaky_relu_4 (TFOpLambda  (None, 208, 208, 64  0          ['batch_normalization_461[0][0]']
#  )                              )
#
#  tf.__operators__.add (TFOpLamb  (None, 208, 208, 64  0          ['tf.nn.leaky_relu_1[0][0]',
#  da)                            )                                 'tf.nn.leaky_relu_4[0][0]']
#
#  zero_padding2d_41 (ZeroPadding  (None, 209, 209, 64  0          ['tf.__operators__.add[0][0]']
#  2D)                            )
#
#  conv2d_214 (Conv2D)            (None, 104, 104, 12  73728       ['zero_padding2d_41[0][0]']
#                                 8)
#
#  batch_normalization_462 (Batch  (None, 104, 104, 12  512        ['conv2d_214[0][0]']
#  Normalization)                 8)
#
#  tf.nn.leaky_relu_5 (TFOpLambda  (None, 104, 104, 12  0          ['batch_normalization_462[0][0]']
#  )                              8)
#
#  depthwise_conv2d_249 (Depthwis  (None, 104, 104, 12  1152       ['tf.nn.leaky_relu_5[0][0]']
#  eConv2D)                       8)
#
#  batch_normalization_464 (Batch  (None, 104, 104, 12  512        ['depthwise_conv2d_249[0][0]']
#  Normalization)                 8)
#
#  tf.nn.leaky_relu_8 (TFOpLambda  (None, 104, 104, 12  0          ['batch_normalization_464[0][0]']
#  )                              8)
#
#  tf.__operators__.add_1 (TFOpLa  (None, 104, 104, 12  0          ['tf.nn.leaky_relu_5[0][0]',
#  mbda)                          8)                                'tf.nn.leaky_relu_8[0][0]']
#
#  depthwise_conv2d_251 (Depthwis  (None, 104, 104, 12  1152       ['tf.__operators__.add_1[0][0]']
#  eConv2D)                       8)
#
#  batch_normalization_466 (Batch  (None, 104, 104, 12  512        ['depthwise_conv2d_251[0][0]']
#  Normalization)                 8)
#
#  tf.nn.leaky_relu_11 (TFOpLambd  (None, 104, 104, 12  0          ['batch_normalization_466[0][0]']
#  a)                             8)
#
#  tf.__operators__.add_2 (TFOpLa  (None, 104, 104, 12  0          ['tf.__operators__.add_1[0][0]',
#  mbda)                          8)                                'tf.nn.leaky_relu_11[0][0]']
#
#  zero_padding2d_42 (ZeroPadding  (None, 105, 105, 12  0          ['tf.__operators__.add_2[0][0]']
#  2D)                            8)
#
#  conv2d_215 (Conv2D)            (None, 52, 52, 256)  294912      ['zero_padding2d_42[0][0]']
#
#  batch_normalization_467 (Batch  (None, 52, 52, 256)  1024       ['conv2d_215[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_12 (TFOpLambd  (None, 52, 52, 256)  0          ['batch_normalization_467[0][0]']
#  a)
#
#  conv2d_216 (Conv2D)            (None, 52, 52, 128)  32768       ['tf.nn.leaky_relu_12[0][0]']
#
#  batch_normalization_468 (Batch  (None, 52, 52, 128)  512        ['conv2d_216[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_13 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_468[0][0]']
#  a)
#
#  conv2d_217 (Conv2D)            (None, 52, 52, 256)  294912      ['tf.nn.leaky_relu_13[0][0]']
#
#  batch_normalization_469 (Batch  (None, 52, 52, 256)  1024       ['conv2d_217[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_14 (TFOpLambd  (None, 52, 52, 256)  0          ['batch_normalization_469[0][0]']
#  a)
#
#  tf.__operators__.add_3 (TFOpLa  (None, 52, 52, 256)  0          ['tf.nn.leaky_relu_12[0][0]',
#  mbda)                                                            'tf.nn.leaky_relu_14[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 52, 52, 128)  32768       ['tf.__operators__.add_3[0][0]']
#
#  batch_normalization_470 (Batch  (None, 52, 52, 128)  512        ['conv2d_218[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_15 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_470[0][0]']
#  a)
#
#  conv2d_219 (Conv2D)            (None, 52, 52, 256)  294912      ['tf.nn.leaky_relu_15[0][0]']
#
#  batch_normalization_471 (Batch  (None, 52, 52, 256)  1024       ['conv2d_219[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_16 (TFOpLambd  (None, 52, 52, 256)  0          ['batch_normalization_471[0][0]']
#  a)
#
#  tf.__operators__.add_4 (TFOpLa  (None, 52, 52, 256)  0          ['tf.nn.leaky_relu_14[0][0]',
#  mbda)                                                            'tf.nn.leaky_relu_12[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 52, 52, 256)  0          ['tf.__operators__.add_4[0][0]',
#  mbda)                                                            'tf.nn.leaky_relu_16[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 52, 52, 128)  32768       ['tf.__operators__.add_5[0][0]']
#
#  batch_normalization_472 (Batch  (None, 52, 52, 128)  512        ['conv2d_220[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_17 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_472[0][0]']
#  a)
#
#  conv2d_221 (Conv2D)            (None, 52, 52, 256)  294912      ['tf.nn.leaky_relu_17[0][0]']
#
#  batch_normalization_473 (Batch  (None, 52, 52, 256)  1024       ['conv2d_221[0][0]']
#  Normalization)
#
#  tf.__operators__.add_6 (TFOpLa  (None, 52, 52, 256)  0          ['tf.nn.leaky_relu_16[0][0]',
#  mbda)                                                            'tf.nn.leaky_relu_14[0][0]']
#
#  tf.nn.leaky_relu_18 (TFOpLambd  (None, 52, 52, 256)  0          ['batch_normalization_473[0][0]']
#  a)
#
#  tf.__operators__.add_7 (TFOpLa  (None, 52, 52, 256)  0          ['tf.__operators__.add_6[0][0]',
#  mbda)                                                            'tf.nn.leaky_relu_12[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 52, 52, 256)  0          ['tf.__operators__.add_7[0][0]',
#  mbda)                                                            'tf.nn.leaky_relu_18[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 52, 52, 128)  32768       ['tf.__operators__.add_8[0][0]']
#
#  batch_normalization_474 (Batch  (None, 52, 52, 128)  512        ['conv2d_222[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_19 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_474[0][0]']
#  a)
#
#  tf.__operators__.add_9 (TFOpLa  (None, 52, 52, 256)  0          ['tf.nn.leaky_relu_12[0][0]',
#  mbda)                                                            'tf.nn.leaky_relu_14[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 52, 52, 256)  294912      ['tf.nn.leaky_relu_19[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 52, 52, 256)  0          ['tf.__operators__.add_9[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_16[0][0]']
#
#  batch_normalization_475 (Batch  (None, 52, 52, 256)  1024       ['conv2d_223[0][0]']
#  Normalization)
#
#  tf.__operators__.add_11 (TFOpL  (None, 52, 52, 256)  0          ['tf.__operators__.add_10[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_18[0][0]']
#
#  tf.nn.leaky_relu_20 (TFOpLambd  (None, 52, 52, 256)  0          ['batch_normalization_475[0][0]']
#  a)
#
#  tf.__operators__.add_12 (TFOpL  (None, 52, 52, 256)  0          ['tf.__operators__.add_11[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_20[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 52, 52, 128)  32768       ['tf.__operators__.add_12[0][0]']
#
#  batch_normalization_476 (Batch  (None, 52, 52, 128)  512        ['conv2d_224[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_21 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_476[0][0]']
#  a)
#
#  conv2d_225 (Conv2D)            (None, 52, 52, 256)  294912      ['tf.nn.leaky_relu_21[0][0]']
#
#  batch_normalization_477 (Batch  (None, 52, 52, 256)  1024       ['conv2d_225[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_22 (TFOpLambd  (None, 52, 52, 256)  0          ['batch_normalization_477[0][0]']
#  a)
#
#  tf.__operators__.add_13 (TFOpL  (None, 52, 52, 256)  0          ['tf.__operators__.add_12[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_22[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 52, 52, 128)  32768       ['tf.__operators__.add_13[0][0]']
#
#  batch_normalization_478 (Batch  (None, 52, 52, 128)  512        ['conv2d_226[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_23 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_478[0][0]']
#  a)
#
#  conv2d_227 (Conv2D)            (None, 52, 52, 256)  294912      ['tf.nn.leaky_relu_23[0][0]']
#
#  batch_normalization_479 (Batch  (None, 52, 52, 256)  1024       ['conv2d_227[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_24 (TFOpLambd  (None, 52, 52, 256)  0          ['batch_normalization_479[0][0]']
#  a)
#
#  tf.__operators__.add_14 (TFOpL  (None, 52, 52, 256)  0          ['tf.nn.leaky_relu_22[0][0]',
#  ambda)                                                           'tf.__operators__.add_12[0][0]']
#
#  tf.__operators__.add_15 (TFOpL  (None, 52, 52, 256)  0          ['tf.__operators__.add_14[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_24[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 52, 52, 128)  32768       ['tf.__operators__.add_15[0][0]']
#
#  batch_normalization_480 (Batch  (None, 52, 52, 128)  512        ['conv2d_228[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_25 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_480[0][0]']
#  a)
#
#  conv2d_229 (Conv2D)            (None, 52, 52, 256)  294912      ['tf.nn.leaky_relu_25[0][0]']
#
#  batch_normalization_481 (Batch  (None, 52, 52, 256)  1024       ['conv2d_229[0][0]']
#  Normalization)
#
#  tf.__operators__.add_16 (TFOpL  (None, 52, 52, 256)  0          ['tf.nn.leaky_relu_24[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_22[0][0]']
#
#  tf.nn.leaky_relu_26 (TFOpLambd  (None, 52, 52, 256)  0          ['batch_normalization_481[0][0]']
#  a)
#
#  tf.__operators__.add_17 (TFOpL  (None, 52, 52, 256)  0          ['tf.__operators__.add_16[0][0]',
#  ambda)                                                           'tf.__operators__.add_12[0][0]']
#
#  tf.__operators__.add_18 (TFOpL  (None, 52, 52, 256)  0          ['tf.__operators__.add_17[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_26[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 52, 52, 128)  32768       ['tf.__operators__.add_18[0][0]']
#
#  batch_normalization_482 (Batch  (None, 52, 52, 128)  512        ['conv2d_230[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_27 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_482[0][0]']
#  a)
#
#  tf.__operators__.add_19 (TFOpL  (None, 52, 52, 256)  0          ['tf.__operators__.add_12[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_22[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 52, 52, 256)  294912      ['tf.nn.leaky_relu_27[0][0]']
#
#  tf.__operators__.add_20 (TFOpL  (None, 52, 52, 256)  0          ['tf.__operators__.add_19[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_24[0][0]']
#
#  batch_normalization_483 (Batch  (None, 52, 52, 256)  1024       ['conv2d_231[0][0]']
#  Normalization)
#
#  tf.__operators__.add_21 (TFOpL  (None, 52, 52, 256)  0          ['tf.__operators__.add_20[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_26[0][0]']
#
#  tf.nn.leaky_relu_28 (TFOpLambd  (None, 52, 52, 256)  0          ['batch_normalization_483[0][0]']
#  a)
#
#  tf.__operators__.add_22 (TFOpL  (None, 52, 52, 256)  0          ['tf.__operators__.add_21[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_28[0][0]']
#
#  zero_padding2d_43 (ZeroPadding  (None, 53, 53, 256)  0          ['tf.__operators__.add_22[0][0]']
#  2D)
#
#  conv2d_232 (Conv2D)            (None, 26, 26, 512)  1179648     ['zero_padding2d_43[0][0]']
#
#  batch_normalization_484 (Batch  (None, 26, 26, 512)  2048       ['conv2d_232[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_29 (TFOpLambd  (None, 26, 26, 512)  0          ['batch_normalization_484[0][0]']
#  a)
#
#  conv2d_233 (Conv2D)            (None, 26, 26, 256)  131072      ['tf.nn.leaky_relu_29[0][0]']
#
#  batch_normalization_485 (Batch  (None, 26, 26, 256)  1024       ['conv2d_233[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_30 (TFOpLambd  (None, 26, 26, 256)  0          ['batch_normalization_485[0][0]']
#  a)
#
#  conv2d_234 (Conv2D)            (None, 26, 26, 512)  1179648     ['tf.nn.leaky_relu_30[0][0]']
#
#  batch_normalization_486 (Batch  (None, 26, 26, 512)  2048       ['conv2d_234[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_31 (TFOpLambd  (None, 26, 26, 512)  0          ['batch_normalization_486[0][0]']
#  a)
#
#  tf.__operators__.add_23 (TFOpL  (None, 26, 26, 512)  0          ['tf.nn.leaky_relu_29[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_31[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 26, 26, 256)  131072      ['tf.__operators__.add_23[0][0]']
#
#  batch_normalization_487 (Batch  (None, 26, 26, 256)  1024       ['conv2d_235[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_32 (TFOpLambd  (None, 26, 26, 256)  0          ['batch_normalization_487[0][0]']
#  a)
#
#  conv2d_236 (Conv2D)            (None, 26, 26, 512)  1179648     ['tf.nn.leaky_relu_32[0][0]']
#
#  batch_normalization_488 (Batch  (None, 26, 26, 512)  2048       ['conv2d_236[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_33 (TFOpLambd  (None, 26, 26, 512)  0          ['batch_normalization_488[0][0]']
#  a)
#
#  tf.__operators__.add_24 (TFOpL  (None, 26, 26, 512)  0          ['tf.nn.leaky_relu_31[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_29[0][0]']
#
#  tf.__operators__.add_25 (TFOpL  (None, 26, 26, 512)  0          ['tf.__operators__.add_24[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_33[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 26, 26, 256)  131072      ['tf.__operators__.add_25[0][0]']
#
#  batch_normalization_489 (Batch  (None, 26, 26, 256)  1024       ['conv2d_237[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_34 (TFOpLambd  (None, 26, 26, 256)  0          ['batch_normalization_489[0][0]']
#  a)
#
#  conv2d_238 (Conv2D)            (None, 26, 26, 512)  1179648     ['tf.nn.leaky_relu_34[0][0]']
#
#  batch_normalization_490 (Batch  (None, 26, 26, 512)  2048       ['conv2d_238[0][0]']
#  Normalization)
#
#  tf.__operators__.add_26 (TFOpL  (None, 26, 26, 512)  0          ['tf.nn.leaky_relu_33[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_31[0][0]']
#
#  tf.nn.leaky_relu_35 (TFOpLambd  (None, 26, 26, 512)  0          ['batch_normalization_490[0][0]']
#  a)
#
#  tf.__operators__.add_27 (TFOpL  (None, 26, 26, 512)  0          ['tf.__operators__.add_26[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_29[0][0]']
#
#  tf.__operators__.add_28 (TFOpL  (None, 26, 26, 512)  0          ['tf.__operators__.add_27[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_35[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 26, 26, 256)  131072      ['tf.__operators__.add_28[0][0]']
#
#  batch_normalization_491 (Batch  (None, 26, 26, 256)  1024       ['conv2d_239[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_36 (TFOpLambd  (None, 26, 26, 256)  0          ['batch_normalization_491[0][0]']
#  a)
#
#  tf.__operators__.add_29 (TFOpL  (None, 26, 26, 512)  0          ['tf.nn.leaky_relu_29[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_31[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 26, 26, 512)  1179648     ['tf.nn.leaky_relu_36[0][0]']
#
#  tf.__operators__.add_30 (TFOpL  (None, 26, 26, 512)  0          ['tf.__operators__.add_29[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_33[0][0]']
#
#  batch_normalization_492 (Batch  (None, 26, 26, 512)  2048       ['conv2d_240[0][0]']
#  Normalization)
#
#  tf.__operators__.add_31 (TFOpL  (None, 26, 26, 512)  0          ['tf.__operators__.add_30[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_35[0][0]']
#
#  tf.nn.leaky_relu_37 (TFOpLambd  (None, 26, 26, 512)  0          ['batch_normalization_492[0][0]']
#  a)
#
#  tf.__operators__.add_32 (TFOpL  (None, 26, 26, 512)  0          ['tf.__operators__.add_31[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_37[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 26, 26, 256)  131072      ['tf.__operators__.add_32[0][0]']
#
#  batch_normalization_493 (Batch  (None, 26, 26, 256)  1024       ['conv2d_241[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_38 (TFOpLambd  (None, 26, 26, 256)  0          ['batch_normalization_493[0][0]']
#  a)
#
#  conv2d_242 (Conv2D)            (None, 26, 26, 512)  1179648     ['tf.nn.leaky_relu_38[0][0]']
#
#  batch_normalization_494 (Batch  (None, 26, 26, 512)  2048       ['conv2d_242[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_39 (TFOpLambd  (None, 26, 26, 512)  0          ['batch_normalization_494[0][0]']
#  a)
#
#  tf.__operators__.add_33 (TFOpL  (None, 26, 26, 512)  0          ['tf.__operators__.add_32[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_39[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 26, 26, 256)  131072      ['tf.__operators__.add_33[0][0]']
#
#  batch_normalization_495 (Batch  (None, 26, 26, 256)  1024       ['conv2d_243[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_40 (TFOpLambd  (None, 26, 26, 256)  0          ['batch_normalization_495[0][0]']
#  a)
#
#  conv2d_244 (Conv2D)            (None, 26, 26, 512)  1179648     ['tf.nn.leaky_relu_40[0][0]']
#
#  batch_normalization_496 (Batch  (None, 26, 26, 512)  2048       ['conv2d_244[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_41 (TFOpLambd  (None, 26, 26, 512)  0          ['batch_normalization_496[0][0]']
#  a)
#
#  tf.__operators__.add_34 (TFOpL  (None, 26, 26, 512)  0          ['tf.nn.leaky_relu_39[0][0]',
#  ambda)                                                           'tf.__operators__.add_32[0][0]']
#
#  tf.__operators__.add_35 (TFOpL  (None, 26, 26, 512)  0          ['tf.__operators__.add_34[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_41[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 26, 26, 256)  131072      ['tf.__operators__.add_35[0][0]']
#
#  batch_normalization_497 (Batch  (None, 26, 26, 256)  1024       ['conv2d_245[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_42 (TFOpLambd  (None, 26, 26, 256)  0          ['batch_normalization_497[0][0]']
#  a)
#
#  conv2d_246 (Conv2D)            (None, 26, 26, 512)  1179648     ['tf.nn.leaky_relu_42[0][0]']
#
#  batch_normalization_498 (Batch  (None, 26, 26, 512)  2048       ['conv2d_246[0][0]']
#  Normalization)
#
#  tf.__operators__.add_36 (TFOpL  (None, 26, 26, 512)  0          ['tf.nn.leaky_relu_41[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_39[0][0]']
#
#  tf.nn.leaky_relu_43 (TFOpLambd  (None, 26, 26, 512)  0          ['batch_normalization_498[0][0]']
#  a)
#
#  tf.__operators__.add_37 (TFOpL  (None, 26, 26, 512)  0          ['tf.__operators__.add_36[0][0]',
#  ambda)                                                           'tf.__operators__.add_32[0][0]']
#
#  tf.__operators__.add_38 (TFOpL  (None, 26, 26, 512)  0          ['tf.__operators__.add_37[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_43[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 26, 26, 256)  131072      ['tf.__operators__.add_38[0][0]']
#
#  batch_normalization_499 (Batch  (None, 26, 26, 256)  1024       ['conv2d_247[0][0]']
#  Normalization)
#
#  tf.nn.leaky_relu_44 (TFOpLambd  (None, 26, 26, 256)  0          ['batch_normalization_499[0][0]']
#  a)
#
#  tf.__operators__.add_39 (TFOpL  (None, 26, 26, 512)  0          ['tf.__operators__.add_32[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_39[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 26, 26, 512)  1179648     ['tf.nn.leaky_relu_44[0][0]']
#
#  tf.__operators__.add_40 (TFOpL  (None, 26, 26, 512)  0          ['tf.__operators__.add_39[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_41[0][0]']
#
#  batch_normalization_500 (Batch  (None, 26, 26, 512)  2048       ['conv2d_248[0][0]']
#  Normalization)
#
#  tf.__operators__.add_41 (TFOpL  (None, 26, 26, 512)  0          ['tf.__operators__.add_40[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_43[0][0]']
#
#  tf.nn.leaky_relu_45 (TFOpLambd  (None, 26, 26, 512)  0          ['batch_normalization_500[0][0]']
#  a)
#
#  tf.__operators__.add_42 (TFOpL  (None, 26, 26, 512)  0          ['tf.__operators__.add_41[0][0]',
#  ambda)                                                           'tf.nn.leaky_relu_45[0][0]']
#
#  zero_padding2d_44 (ZeroPadding  (None, 27, 27, 512)  0          ['tf.__operators__.add_42[0][0]']
#  2D)
#
#  conv2d_249 (Conv2D)            (None, 13, 13, 1024  4718592     ['zero_padding2d_44[0][0]']
#                                 )
#
#  batch_normalization_501 (Batch  (None, 13, 13, 1024  4096       ['conv2d_249[0][0]']
#  Normalization)                 )
#
#  tf.nn.leaky_relu_46 (TFOpLambd  (None, 13, 13, 1024  0          ['batch_normalization_501[0][0]']
#  a)                             )
# ...
#                                                                  0]']
#
#  tf.__operators__.getitem_32 (S  (1, 13, 13, 1, 2)   0           ['tf.concat_8[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_2 (Sl  (None, 52, 52, 3, 2  0          ['tf.reshape[0][0]']
#  icingOpLambda)                 )
#
#  tf.tile_2 (TFOpLambda)         (None, 52, 52, 3, 2  0           ['tf.__operators__.getitem_10[0][
#                                 )                                0]',
#                                                                   'tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.__operators__.getitem_3 (Sl  (None, 52, 52, 3, 2  0          ['tf.reshape[0][0]']
#  icingOpLambda)                 )
#
#  tf.__operators__.getitem_13 (S  (None, 26, 26, 3, 2  0          ['tf.reshape_1[0][0]']
#  licingOpLambda)                )
#
#  tf.tile_5 (TFOpLambda)         (None, 26, 26, 3, 2  0           ['tf.__operators__.getitem_21[0][
#                                 )                                0]',
#                                                                   'tf.__operators__.getitem_11[0][
#                                                                  0]']
#
#  tf.__operators__.getitem_14 (S  (None, 26, 26, 3, 2  0          ['tf.reshape_1[0][0]']
#  licingOpLambda)                )
#
#  tf.__operators__.getitem_24 (S  (None, 13, 13, 3, 2  0          ['tf.reshape_2[0][0]']
#  licingOpLambda)                )
#
#  tf.tile_8 (TFOpLambda)         (None, 13, 13, 3, 2  0           ['tf.__operators__.getitem_32[0][
#                                 )                                0]',
#                                                                   'tf.__operators__.getitem_22[0][
#                                                                  0]']
#
#  tf.__operators__.getitem_25 (S  (None, 13, 13, 3, 2  0          ['tf.reshape_2[0][0]']
#  licingOpLambda)                )
#
#  tf.math.sigmoid (TFOpLambda)   (None, 52, 52, 3, 2  0           ['tf.__operators__.getitem_2[0][0
#                                 )                                ]']
#
#  tf.cast (TFOpLambda)           (None, 52, 52, 3, 2  0           ['tf.tile_2[0][0]']
#                                 )
#
#  tf.math.exp (TFOpLambda)       (None, 52, 52, 3, 2  0           ['tf.__operators__.getitem_3[0][0
#                                 )                                ]']
#
#  tf.math.sigmoid_3 (TFOpLambda)  (None, 26, 26, 3, 2  0          ['tf.__operators__.getitem_13[0][
#                                 )                                0]']
#
#  tf.cast_1 (TFOpLambda)         (None, 26, 26, 3, 2  0           ['tf.tile_5[0][0]']
#                                 )
#
#  tf.math.exp_1 (TFOpLambda)     (None, 26, 26, 3, 2  0           ['tf.__operators__.getitem_14[0][
#                                 )                                0]']
#
#  tf.math.sigmoid_6 (TFOpLambda)  (None, 13, 13, 3, 2  0          ['tf.__operators__.getitem_24[0][
#                                 )                                0]']
#
#  tf.cast_2 (TFOpLambda)         (None, 13, 13, 3, 2  0           ['tf.tile_8[0][0]']
#                                 )
#
#  tf.math.exp_2 (TFOpLambda)     (None, 13, 13, 3, 2  0           ['tf.__operators__.getitem_25[0][
#                                 )                                0]']
#
#  tf.__operators__.add_47 (TFOpL  (None, 52, 52, 3, 2  0          ['tf.math.sigmoid[0][0]',
#  ambda)                         )                                 'tf.cast[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 52, 52, 3, 2  0          ['tf.math.exp[0][0]']
#  )                              )
#
#  tf.__operators__.add_48 (TFOpL  (None, 26, 26, 3, 2  0          ['tf.math.sigmoid_3[0][0]',
#  ambda)                         )                                 'tf.cast_1[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 26, 26, 3, 2  0          ['tf.math.exp_1[0][0]']
#  )                              )
#
#  tf.__operators__.add_49 (TFOpL  (None, 13, 13, 3, 2  0          ['tf.math.sigmoid_6[0][0]',
#  ambda)                         )                                 'tf.cast_2[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 13, 13, 3, 2  0          ['tf.math.exp_2[0][0]']
#  )                              )
#
#  tf.math.multiply (TFOpLambda)  (None, 52, 52, 3, 2  0           ['tf.__operators__.add_47[0][0]']
#                                 )
#
#  tf.math.multiply_2 (TFOpLambda  (None, 52, 52, 3, 2  0          ['tf.math.multiply_1[0][0]']
#  )                              )
#
#  tf.__operators__.getitem_4 (Sl  (None, 52, 52, 3, 1  0          ['tf.reshape[0][0]']
#  icingOpLambda)                 )
#
#  tf.__operators__.getitem_5 (Sl  (None, 52, 52, 3, 8  0          ['tf.reshape[0][0]']
#  icingOpLambda)                 0)
#
#  tf.math.multiply_3 (TFOpLambda  (None, 26, 26, 3, 2  0          ['tf.__operators__.add_48[0][0]']
#  )                              )
#
#  tf.math.multiply_5 (TFOpLambda  (None, 26, 26, 3, 2  0          ['tf.math.multiply_4[0][0]']
#  )                              )
#
#  tf.__operators__.getitem_15 (S  (None, 26, 26, 3, 1  0          ['tf.reshape_1[0][0]']
#  licingOpLambda)                )
#
#  tf.__operators__.getitem_16 (S  (None, 26, 26, 3, 8  0          ['tf.reshape_1[0][0]']
#  licingOpLambda)                0)
#
#  tf.math.multiply_6 (TFOpLambda  (None, 13, 13, 3, 2  0          ['tf.__operators__.add_49[0][0]']
#  )                              )
#
#  tf.math.multiply_8 (TFOpLambda  (None, 13, 13, 3, 2  0          ['tf.math.multiply_7[0][0]']
#  )                              )
#
#  tf.__operators__.getitem_26 (S  (None, 13, 13, 3, 1  0          ['tf.reshape_2[0][0]']
#  licingOpLambda)                )
#
#  tf.__operators__.getitem_27 (S  (None, 13, 13, 3, 8  0          ['tf.reshape_2[0][0]']
#  licingOpLambda)                0)
#
#  tf.concat_3 (TFOpLambda)       (None, 52, 52, 3, 4  0           ['tf.math.multiply[0][0]',
#                                 )                                 'tf.math.multiply_2[0][0]']
#
#  tf.math.sigmoid_1 (TFOpLambda)  (None, 52, 52, 3, 1  0          ['tf.__operators__.getitem_4[0][0
#                                 )                                ]']
#
#  tf.math.sigmoid_2 (TFOpLambda)  (None, 52, 52, 3, 8  0          ['tf.__operators__.getitem_5[0][0
#                                 0)                               ]']
#
#  tf.concat_6 (TFOpLambda)       (None, 26, 26, 3, 4  0           ['tf.math.multiply_3[0][0]',
#                                 )                                 'tf.math.multiply_5[0][0]']
#
#  tf.math.sigmoid_4 (TFOpLambda)  (None, 26, 26, 3, 1  0          ['tf.__operators__.getitem_15[0][
#                                 )                                0]']
#
#  tf.math.sigmoid_5 (TFOpLambda)  (None, 26, 26, 3, 8  0          ['tf.__operators__.getitem_16[0][
#                                 0)                               0]']
#
#  tf.concat_9 (TFOpLambda)       (None, 13, 13, 3, 4  0           ['tf.math.multiply_6[0][0]',
#                                 )                                 'tf.math.multiply_8[0][0]']
#
#  tf.math.sigmoid_7 (TFOpLambda)  (None, 13, 13, 3, 1  0          ['tf.__operators__.getitem_26[0][
#                                 )                                0]']
#
#  tf.math.sigmoid_8 (TFOpLambda)  (None, 13, 13, 3, 8  0          ['tf.__operators__.getitem_27[0][
#                                 0)                               0]']
#
#  tf.concat_4 (TFOpLambda)       (None, 52, 52, 3, 8  0           ['tf.concat_3[0][0]',
#                                 5)                                'tf.math.sigmoid_1[0][0]',
#                                                                   'tf.math.sigmoid_2[0][0]']
#
#  tf.concat_7 (TFOpLambda)       (None, 26, 26, 3, 8  0           ['tf.concat_6[0][0]',
#                                 5)                                'tf.math.sigmoid_4[0][0]',
#                                                                   'tf.math.sigmoid_5[0][0]']
#
#  tf.concat_10 (TFOpLambda)      (None, 13, 13, 3, 8  0           ['tf.concat_9[0][0]',
#                                 5)                                'tf.math.sigmoid_7[0][0]',
#                                                                   'tf.math.sigmoid_8[0][0]']
#
# ==================================================================================================
# Total params: 40,876,829
# Trainable params: 40,828,637
# Non-trainable params: 48,192
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training

# %%
trainset = Dataset('train')

# %%
logdir = "/content/drive/MyDrive/yolov3_research_implementation/mnist_data/training/log"
steps_per_epoch = len(trainset)
global_steps = tf.Variable(1, trainable=False, dtype=tf.int64)
warmup_steps = cfg.TRAIN.WARMUP_EPOCHS * steps_per_epoch
total_steps = cfg.TRAIN.EPOCHS * steps_per_epoch

# %%
# model.summary()

# %%
if os.path.exists(logdir): shutil.rmtree(logdir)
writer = tf.summary.create_file_writer(logdir)

# %%
def train_step(image_data, target):
    with tf.GradientTape() as tape:
        pred_result = model(image_data, training=True)
        giou_loss=conf_loss=prob_loss=0

        # optimizing process
        for i in range(3):
            conv, pred = pred_result[i*2], pred_result[i*2+1]
            loss_items = compute_loss(pred, conv, *target[i], i)
            giou_loss += loss_items[0]
            conf_loss += loss_items[1]
            prob_loss += loss_items[2]

        total_loss = giou_loss + conf_loss + prob_loss

        gradients = tape.gradient(total_loss, model.trainable_variables)
        optimizer.apply_gradients(zip(gradients, model.trainable_variables))
        tf.print("=> STEP %4d   lr: %.6f   giou_loss: %4.2f   conf_loss: %4.2f   "
                 "prob_loss: %4.2f   total_loss: %4.2f" %(global_steps, optimizer.lr.numpy(),
                                                          giou_loss, conf_loss,
                                                          prob_loss, total_loss))
        # update learning rate
        global_steps.assign_add(1)
        if global_steps < warmup_steps:
            lr = global_steps / warmup_steps *cfg.TRAIN.LR_INIT
        else:
            lr = cfg.TRAIN.LR_END + 0.5 * (cfg.TRAIN.LR_INIT - cfg.TRAIN.LR_END) * (
                (1 + tf.cos((global_steps - warmup_steps) / (total_steps - warmup_steps) * np.pi))
            )
        optimizer.lr.assign(lr.numpy())

        # writing summary data
        with writer.as_default():
            tf.summary.scalar("lr", optimizer.lr, step=global_steps)
            tf.summary.scalar("loss/total_loss", total_loss, step=global_steps)
            tf.summary.scalar("loss/giou_loss", giou_loss, step=global_steps)
            tf.summary.scalar("loss/conf_loss", conf_loss, step=global_steps)
            tf.summary.scalar("loss/prob_loss", prob_loss, step=global_steps)
        writer.flush()

# %%
for epoch in range(cfg.TRAIN.EPOCHS):
    for image_data, target in trainset:
        train_step(image_data, target)
    model.save_weights("./yolov3")
# Out:
# => STEP    2   lr: 0.000004   giou_loss: 21.00   conf_loss: 1462.37   prob_loss: 1026.75   total_loss: 2510.12
# => STEP    3   lr: 0.000006   giou_loss: 13.51   conf_loss: 1475.75   prob_loss: 568.30   total_loss: 2057.55
# => STEP    4   lr: 0.000008   giou_loss: 23.78   conf_loss: 1470.69   prob_loss: 1168.57   total_loss: 2663.04
